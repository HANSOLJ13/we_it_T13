# %% [markdown]
# ###train_test_split()
# - test_size: test dataset의 비율
# - random_state: 호출할 때마다 같은 train/test data를 생성하기 위해 지정(지정하지 않으면 무작위)
#
# ###acccuracy_score()
# - 정확도 측정
#
# ##과정
# 1. train/test data split
# 2. train data로 모델 학습
# 3. 모델로 test set의 타겟값을 예측
# 4. 모델 성능 평가
# ---
#
# ##사이킷런 주요 모듈
# ###예제 데이터
# - sklearn.datasets
#
# ###피처처리
# - sklearn.preprocessing (lable encoding: 숫자로 변환, 선형 회귀X 트리 계열O / one-hot encoding: 고유값 1, 나머지 0)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - sklearn.feature_selection
# - sklearn.feature_extraction
# - sklearn.decomposition (차원 축소)
#
# ###데이터 분리, grid search
# - sklearn.model_selection (GridSearchCV)
#
# ###평가
# - sklearn.metrics (KFold: cross validation)
#
# ###머신러닝 알고리즘
# - sklearn.ensemble
# - sklearn.linear_model
# - sklearn.naive_bayes
# - sklearn.neighbors
# - sklearn.svm
# - sklearn.tree
# - sklearn.cluster
#
# ###유틸리티
# - sklearn.pipeline
